# %% [markdown]
# # Loading the clean - masked data into the Target Database.

# %%
#We use the masked data for loading into the database as the data contains sensitive information.

# %%
import pandas as pd
import numpy as np

# %%
masked_cleaned_df = pd.read_csv('C:/Users/s.a.gowrishankar/OneDrive - Accenture/Documents/masked_salary_info.csv')

# %%
masked_cleaned_df.head(10)
# Out:
#        Id          EmployeeName                        JobTitle    BasePay  \
# 0  110532           *******hinn                  Deputy Chief 3  129150.01
# 1  110533            ******Hart               Asst Med Examiner  318835.49
# 2  110534  **************** Jr.        Chief Investment Officer  257340.00
# 3  110535        **********Suhr                 Chief of Police  307450.04
# 4  110536  ****************hite          Chief, Fire Department  302068.00
# 5  110537       ***********fatt               Asst Med Examiner  270222.04
# 6  110538         *********rtin                     Dept Head V  311298.55
# 7  110539     *************y-Jr     Executive Contract Employee  310161.02
# 8  110540            ****** Lai  Battalion Chief, Fire Suppress  179464.14
# 9  110541      ************klin    Asst Chf of Dept (Fire Dept)  201566.88
#
#    OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# ...

# %%
import sqlalchemy
import pandas as pd 
from sqlalchemy.orm import sessionmaker
import requests
import json 
from datetime import datetime
import datetime 
import sqlite3 
DATABASE_LOCATION = "sqlite:///masked_salary_info_tracker.sqlite"
engine = sqlalchemy.create_engine(DATABASE_LOCATION)
conn = sqlite3.connect('sf_salary_masked.sqlite')
cursor = conn.cursor()

# %%
sql_query = """ 
CREATE TABLE IF NOT EXISTS masked_salary_info_tracker_sf(
    Id VARCHAR(200),
    EmployeeName VARCHAR(200),
    JobTitle VARCHAR(200),
    timestamp VARCHAR(200),
    BasePay VARCHAR(200),
    OvertimePay VARCHAR(200),
    OtherPay VARCHAR(200),
    Benefits VARCHAR(200),
    TotalPay VARCHAR(200),
    TotalPaybenefits VARCHAR(200),
    Year VARCHAR(200),
    Agency VARCHAR(200),
    Status VARCHAR(200),
    IngestTime VARCHAR(200),
    IngestDate VARCHAR(200),
    CONSTRAINT primary_key_constraint PRIMARY KEY (Id)
    )
"""
cursor.execute(sql_query)
print("Opened Database successfully")


try:
    masked_cleaned_df.to_sql("masked_salary_info_tracker_sf", engine, index=False, if_exists='append')
except:
    print("Data already exists")
    
conn.close()
print("Closed db successfully")
# Out:
# Opened Database successfully
# Data already exists
# Closed db successfully
